# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("carprices.csv")
df = pd.DataFrame(data)
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
sns.pairplot(data)

# %%
from sklearn.model_selection import  train_test_split
X = df.drop(['Sell Price($)'], axis='columns')
y = df['Sell Price($)']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
print(len(X_train))
# Out:
# 14

# %%
print(len(X))
# Out:
# 20

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([23213.92100798, 39087.89185618, 39542.67542415, 21008.81156356,
#        34854.08172289, 15777.22991655])

# %%
model.score(X_test, y_test)
# Out:
# 0.9455602292160576

# %%
X_train, X_test, y_train,y_test = train_test_split(X, y, test_size=0.3)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([23208.32387717, 40003.34609431, 26899.06029358, 22305.17874317,
#        29156.92312858, 39518.7749036 ])

# %%
model.score(X_test, y_test)
# Out:
# 0.8737300053997923
